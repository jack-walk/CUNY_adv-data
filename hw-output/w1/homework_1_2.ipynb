# %% [markdown]
# ### Homework 1.2: Python Practice
#
# For this assignment, you will need to install a Python library called pycountry. You can do this from the terminal by running the following command: pip3 install pycountry
#
# You can run this same command in your VSCode terminal.

# %%
#Install pycountry library
pip install pycountry
# Out:
#   Cell In[19], line 2
#     pip install pycountry
#         ^
# SyntaxError: invalid syntax

# %%
# Import the pycountry library.
import pycountry

# %%
# Check how many countries are in the library.
len(pycountry.countries)
# Out:
# 249

# %%
# Loop through every country in the pycountries library. 
# The data type for each country is a tuple. 
# Let's convert and display each country as a dictionary. 

for country in pycountry.countries:
    print(dict(country))
# Out:
# {'alpha_2': 'AW', 'alpha_3': 'ABW', 'flag': '🇦🇼', 'name': 'Aruba', 'numeric': '533'}
# {'alpha_2': 'AF', 'alpha_3': 'AFG', 'flag': '🇦🇫', 'name': 'Afghanistan', 'numeric': '004', 'official_name': 'Islamic Republic of Afghanistan'}
# {'alpha_2': 'AO', 'alpha_3': 'AGO', 'flag': '🇦🇴', 'name': 'Angola', 'numeric': '024', 'official_name': 'Republic of Angola'}
# {'alpha_2': 'AI', 'alpha_3': 'AIA', 'flag': '🇦🇮', 'name': 'Anguilla', 'numeric': '660'}
# {'alpha_2': 'AX', 'alpha_3': 'ALA', 'flag': '🇦🇽', 'name': 'Åland Islands', 'numeric': '248'}
# {'alpha_2': 'AL', 'alpha_3': 'ALB', 'flag': '🇦🇱', 'name': 'Albania', 'numeric': '008', 'official_name': 'Republic of Albania'}
# {'alpha_2': 'AD', 'alpha_3': 'AND', 'flag': '🇦🇩', 'name': 'Andorra', 'numeric': '020', 'official_name': 'Principality of Andorra'}
# {'alpha_2': 'AE', 'alpha_3': 'ARE', 'flag': '🇦🇪', 'name': 'United Arab Emirates', 'numeric': '784'}
# ...

# %% [markdown]
# Now your turn. Loop through the countries and print every flag.

# %%
# Loop through every country in the pycountries library and print flags. 

for flags in pycountry.countries:
    print(dict(flags))
# Out:
# {'alpha_2': 'AW', 'alpha_3': 'ABW', 'flag': '🇦🇼', 'name': 'Aruba', 'numeric': '533'}
# {'alpha_2': 'AF', 'alpha_3': 'AFG', 'flag': '🇦🇫', 'name': 'Afghanistan', 'numeric': '004', 'official_name': 'Islamic Republic of Afghanistan'}
# {'alpha_2': 'AO', 'alpha_3': 'AGO', 'flag': '🇦🇴', 'name': 'Angola', 'numeric': '024', 'official_name': 'Republic of Angola'}
# {'alpha_2': 'AI', 'alpha_3': 'AIA', 'flag': '🇦🇮', 'name': 'Anguilla', 'numeric': '660'}
# {'alpha_2': 'AX', 'alpha_3': 'ALA', 'flag': '🇦🇽', 'name': 'Åland Islands', 'numeric': '248'}
# {'alpha_2': 'AL', 'alpha_3': 'ALB', 'flag': '🇦🇱', 'name': 'Albania', 'numeric': '008', 'official_name': 'Republic of Albania'}
# {'alpha_2': 'AD', 'alpha_3': 'AND', 'flag': '🇦🇩', 'name': 'Andorra', 'numeric': '020', 'official_name': 'Principality of Andorra'}
# {'alpha_2': 'AE', 'alpha_3': 'ARE', 'flag': '🇦🇪', 'name': 'United Arab Emirates', 'numeric': '784'}
# ...

# %% [markdown]
# Let's take it a step further. Add each flag to a list called flags.

# %%
for country in pycountry.countries:
    print(dict(country))

flags.append(dict(country))
flags.head(10))

# %% [markdown]
# Now use a loop to populate an empty dictionary.
# The keys should be country names, and the values should be flags.

# %%
# Now let's do some file writing. Create a new csv file and populate it using the dictionary you just built.
# Don't forget to
